# %%
# Change directory to VSCode workspace root so that relative path loads work correctly. Turn this addition off with the DataScience.changeDirOnImportExport setting
# ms-python.python added
import os
try:
	os.chdir(os.path.join(os.getcwd(), '..'))
	print(os.getcwd())
except:
	pass

# %%
import sys, os
sys.path.append(os.getcwd())
import assignment2.Networks as Networks
import assignment2.mnistLoader as mnistLoader
import numpy as np
import pickle
import matplotlib.pyplot as plt 

trainFile = 'data/mnist/train.zip'
testFile = 'data/mnist/test.zip'

# %%
try:
    with open('data/mnist/allData.pkl', 'rb') as allData:
        trainData, validationData, testData = pickle.load(allData)
except:
    trainData, validationData, testData = mnistLoader.loadAll(trainFile, testFile)
    with open('data/mnist/allData.pkl', 'wb') as allData:
        pickle.dump((trainData, validationData, testData), allData)
        print('all data have been dumped into file')

# %%
trainData, validationData, testData = list(trainData), list(validationData), list(testData)
# plt.imshow(trainData[0][1846], cmap='gray')
# plt.title(trainData[1][1846])
# plt.show()
trainData[0] = trainData[0].reshape((-1,784))/255
validationData[0] = validationData[0].reshape((-1,784))/255
testData[0] = testData[0].reshape((-1,784))/255

# %%
print('\n Begin training a single layer net')
oneLayerNet = Networks.FCNet((784,10), 'sigmoid')
oneLayerNet.gradientDescent(trainData, 30, 11, 0.1, valData=validationData)
oneLayerNet.report(testData)
# Out:
#  Begin training a single layer net
# The 0th epoch completed
# On trainData, correctly classify 37535.0/42000 images.
# On trainData, correctly classify 15973.0/18000 images.
# The 1th epoch completed
# On trainData, correctly classify 37151.0/42000 images.
# On trainData, correctly classify 15723.0/18000 images.
# The 2th epoch completed
# On trainData, correctly classify 36681.0/42000 images.
# On trainData, correctly classify 15607.0/18000 images.
# The 3th epoch completed
# On trainData, correctly classify 37790.0/42000 images.
# On trainData, correctly classify 15955.0/18000 images.
# The 4th epoch completed
# On trainData, correctly classify 35672.0/42000 images.
# On trainData, correctly classify 15117.0/18000 images.
# The 5th epoch completed
# On trainData, correctly classify 35463.0/42000 images.
# On trainData, correctly classify 15099.0/18000 images.
# The 6th epoch completed
# On trainData, correctly classify 38096.0/42000 images.
# On trainData, correctly classify 16099.0/18000 images.
# The 7th epoch completed
# On trainData, correctly classify 38005.0/42000 images.
# On trainData, correctly classify 16054.0/18000 images.
# The 8th epoch completed
# On trainData, correctly classify 38044.0/42000 images.
# On trainData, correctly classify 16038.0/18000 images.
# The 9th epoch completed
# On trainData, correctly classify 38133.0/42000 images.
# On trainData, correctly classify 16055.0/18000 images.
# The 10th epoch completed
# On trainData, correctly classify 37232.0/42000 images.
# On trainData, correctly classify 15739.0/18000 images.
# The 11th epoch completed
# On trainData, correctly classify 38785.0/42000 images.
# On trainData, correctly classify 16269.0/18000 images.
# The 12th epoch completed
# On trainData, correctly classify 38465.0/42000 images.
# On trainData, correctly classify 16174.0/18000 images.
# The 13th epoch completed
# On trainData, correctly classify 38223.0/42000 images.
# On trainData, correctly classify 16073.0/18000 images.
# The 14th epoch completed
# On trainData, correctly classify 37610.0/42000 images.
# On trainData, correctly classify 15866.0/18000 images.
# The 15th epoch completed
# On trainData, correctly classify 36931.0/42000 images.
# On trainData, correctly classify 15560.0/18000 images.
# The 16th epoch completed
# On trainData, correctly classify 37508.0/42000 images.
# On trainData, correctly classify 15817.0/18000 images.
# The 17th epoch completed
# On trainData, correctly classify 38596.0/42000 images.
# On trainData, correctly classify 16233.0/18000 images.
# The 18th epoch completed
# On trainData, correctly classify 37811.0/42000 images.
# On trainData, correctly classify 15938.0/18000 images.
# The 19th epoch completed
# On trainData, correctly classify 38177.0/42000 images.
# On trainData, correctly classify 16052.0/18000 images.
# The 20th epoch completed
# On trainData, correctly classify 38152.0/42000 images.
# On trainData, correctly classify 16058.0/18000 images.
# The 21th epoch completed
# On trainData, correctly classify 37763.0/42000 images.
# On trainData, correctly classify 15960.0/18000 images.
# The 22th epoch completed
# On trainData, correctly classify 37528.0/42000 images.
# On trainData, correctly classify 15794.0/18000 images.
# The 23th epoch completed
# On trainData, correctly classify 37348.0/42000 images.
# On trainData, correctly classify 15731.0/18000 images.
# The 24th epoch completed
# On trainData, correctly classify 37677.0/42000 images.
# On trainData, correctly classify 15876.0/18000 images.
# The 25th epoch completed
# On trainData, correctly classify 38279.0/42000 images.
# On trainData, correctly classify 16051.0/18000 images.
# The 26th epoch completed
# On trainData, correctly classify 38515.0/42000 images.
# On trainData, correctly classify 16188.0/18000 images.
# The 27th epoch completed
# On trainData, correctly classify 38390.0/42000 images.
# On trainData, correctly classify 16132.0/18000 images.
# The 28th epoch completed
# On trainData, correctly classify 38044.0/42000 images.
# On trainData, correctly classify 15951.0/18000 images.
# The 29th epoch completed
# On trainData, correctly classify 38529.0/42000 images.
# On trainData, correctly classify 16119.0/18000 images.
#
# On test set, correctly classify 8994.0/10000 images.

# %%
print('\n Begin training a double layer net')
twoLayerNet = Networks.FCNet((784,30,10), 'sigmoid')
twoLayerNet.gradientDescent(trainData, 30, 11, 0.1, valData=validationData)
twoLayerNet.report(testData)
# Out:
#  Begin training a double layer net
# The 0th epoch completed
# On trainData, correctly classify 34709.0/42000 images.
# On trainData, correctly classify 14810.0/18000 images.
# The 1th epoch completed
# On trainData, correctly classify 35168.0/42000 images.
# On trainData, correctly classify 15016.0/18000 images.
# The 2th epoch completed
# On trainData, correctly classify 36129.0/42000 images.
# On trainData, correctly classify 15415.0/18000 images.
# The 3th epoch completed
# On trainData, correctly classify 36837.0/42000 images.
# On trainData, correctly classify 15711.0/18000 images.
# The 4th epoch completed
# On trainData, correctly classify 36956.0/42000 images.
# On trainData, correctly classify 15769.0/18000 images.
# The 5th epoch completed
# On trainData, correctly classify 36716.0/42000 images.
# On trainData, correctly classify 15661.0/18000 images.
# The 6th epoch completed
# On trainData, correctly classify 36909.0/42000 images.
# On trainData, correctly classify 15752.0/18000 images.
# The 7th epoch completed
# On trainData, correctly classify 36982.0/42000 images.
# On trainData, correctly classify 15761.0/18000 images.
# The 8th epoch completed
# On trainData, correctly classify 36949.0/42000 images.
# On trainData, correctly classify 15784.0/18000 images.
# The 9th epoch completed
# On trainData, correctly classify 36835.0/42000 images.
# On trainData, correctly classify 15749.0/18000 images.
# The 10th epoch completed
# On trainData, correctly classify 36951.0/42000 images.
# On trainData, correctly classify 15732.0/18000 images.
# The 11th epoch completed
# On trainData, correctly classify 36994.0/42000 images.
# On trainData, correctly classify 15766.0/18000 images.
# The 12th epoch completed
# On trainData, correctly classify 36943.0/42000 images.
# On trainData, correctly classify 15754.0/18000 images.
# The 13th epoch completed
# On trainData, correctly classify 36763.0/42000 images.
# On trainData, correctly classify 15649.0/18000 images.
# The 14th epoch completed
# On trainData, correctly classify 37013.0/42000 images.
# On trainData, correctly classify 15762.0/18000 images.
# The 15th epoch completed
# On trainData, correctly classify 36873.0/42000 images.
# On trainData, correctly classify 15727.0/18000 images.
# The 16th epoch completed
# On trainData, correctly classify 36785.0/42000 images.
# On trainData, correctly classify 15654.0/18000 images.
# The 17th epoch completed
# On trainData, correctly classify 36427.0/42000 images.
# On trainData, correctly classify 15547.0/18000 images.
# The 18th epoch completed
# On trainData, correctly classify 36833.0/42000 images.
# On trainData, correctly classify 15723.0/18000 images.
# The 19th epoch completed
# On trainData, correctly classify 36629.0/42000 images.
# On trainData, correctly classify 15579.0/18000 images.
# The 20th epoch completed
# On trainData, correctly classify 36589.0/42000 images.
# On trainData, correctly classify 15601.0/18000 images.
# The 21th epoch completed
# On trainData, correctly classify 36535.0/42000 images.
# On trainData, correctly classify 15589.0/18000 images.
# The 22th epoch completed
# On trainData, correctly classify 36767.0/42000 images.
# On trainData, correctly classify 15721.0/18000 images.
# The 23th epoch completed
# On trainData, correctly classify 36675.0/42000 images.
# On trainData, correctly classify 15613.0/18000 images.
# The 24th epoch completed
# On trainData, correctly classify 36682.0/42000 images.
# On trainData, correctly classify 15692.0/18000 images.
# The 25th epoch completed
# On trainData, correctly classify 36604.0/42000 images.
# On trainData, correctly classify 15618.0/18000 images.
# The 26th epoch completed
# On trainData, correctly classify 36710.0/42000 images.
# On trainData, correctly classify 15693.0/18000 images.
# The 27th epoch completed
# On trainData, correctly classify 36457.0/42000 images.
# On trainData, correctly classify 15589.0/18000 images.
# The 28th epoch completed
# On trainData, correctly classify 36441.0/42000 images.
# On trainData, correctly classify 15627.0/18000 images.
# The 29th epoch completed
# On trainData, correctly classify 36708.0/42000 images.
# On trainData, correctly classify 15646.0/18000 images.
#
# On test set, correctly classify 8708.0/10000 images.
